# %% [markdown]
# <a href="https://colab.research.google.com/github/hedaootanisha/Customer_Analysis/blob/main/Customer_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Preparation and Customer Analytics

# %% [markdown]
# 1.importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2.loading the provided datasets
#
#
# 1.   Purchase Behaviour
# 2.   Transaction Data

# %%
df_csv=pd.read_csv('/content/QVI_purchase_behaviour.csv')
print("PURCHASE BEHAVIOUR")
print(df_csv.head())
# Out:
# PURCHASE BEHAVIOUR
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream

# %%
df_excel=pd.read_excel('/content/QVI_transaction_data.xlsx')
print("TRANSACTION DATA")
print(df_excel.head())
# Out:
# TRANSACTION DATA
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8

# %% [markdown]
# 3.Data Checks

# %% [markdown]
# for Purchase Behaviour

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df_csv.describe()
# Out:
#        LYLTY_CARD_NBR
# count    7.263700e+04
# mean     1.361859e+05
# std      8.989293e+04
# min      1.000000e+03
# 25%      6.620200e+04
# 50%      1.340400e+05
# 75%      2.033750e+05
# max      2.373711e+06

# %%
df_csv.shape
# Out:
# (72637, 3)

# %%
df_csv.sum()
# Out:
# LYLTY_CARD_NBR                                             9892137526
# LIFESTAGE           YOUNG SINGLES/COUPLESYOUNG SINGLES/COUPLESYOUN...
# PREMIUM_CUSTOMER    PremiumMainstreamBudgetMainstreamMainstreamBud...
# dtype: object

# %%
df_csv.isnull()
# Out:
#        LYLTY_CARD_NBR  LIFESTAGE  PREMIUM_CUSTOMER
# 0               False      False             False
# 1               False      False             False
# 2               False      False             False
# 3               False      False             False
# 4               False      False             False
# ...               ...        ...               ...
# 72632           False      False             False
# 72633           False      False             False
# 72634           False      False             False
# 72635           False      False             False
# 72636           False      False             False
#
# [72637 rows x 3 columns]

# %%
df_csv.isnull().sum()
# Out:
# LYLTY_CARD_NBR      0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
(df_csv.isnull().sum() / len(df_csv)) * 100
# Out:
# LYLTY_CARD_NBR      0.0
# LIFESTAGE           0.0
# PREMIUM_CUSTOMER    0.0
# dtype: float64

# %% [markdown]
# for Transaction data

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %%
df_excel.describe()
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# ...

# %%
df_excel.tail()
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES
# 264831  Kettle Sweet Chilli And Sour Cream 175g         2       10.8
# 264832            Tostitos Splash Of  Lime 175g         1        4.4
# 264833                 Doritos Mexicana    170g         2        8.8
# 264834  Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 264835            Tostitos Splash Of  Lime 175g         2        8.8

# %%
df_excel.shape
# Out:
# (264836, 8)

# %%
df_excel.sum()
# Out:
# DATE                                                    11510841507
# STORE_NBR                                                  35774076
# LYLTY_CARD_NBR                                          35898381133
# TXN_ID                                                  35794786403
# PROD_NBR                                                   14985257
# PROD_NAME         Natural Chip        Compny SeaSalt175gCCs Nach...
# PROD_QTY                                                     505124
# TOT_SALES                                                 1934415.0
# dtype: object

# %%
df_excel.isnull()
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  PROD_NAME  \
# 0       False      False           False   False     False      False
# 1       False      False           False   False     False      False
# 2       False      False           False   False     False      False
# 3       False      False           False   False     False      False
# 4       False      False           False   False     False      False
# ...       ...        ...             ...     ...       ...        ...
# 264831  False      False           False   False     False      False
# 264832  False      False           False   False     False      False
# 264833  False      False           False   False     False      False
# 264834  False      False           False   False     False      False
# 264835  False      False           False   False     False      False
#
#         PROD_QTY  TOT_SALES
# 0          False      False
# 1          False      False
# 2          False      False
# ...

# %%
df_excel.isnull().sum()
# Out:
# DATE              0
# STORE_NBR         0
# LYLTY_CARD_NBR    0
# TXN_ID            0
# PROD_NBR          0
# PROD_NAME         0
# PROD_QTY          0
# TOT_SALES         0
# dtype: int64

# %%
(df_excel.isnull().sum() / len(df_excel)) * 100
# Out:
# DATE              0.0
# STORE_NBR         0.0
# LYLTY_CARD_NBR    0.0
# TXN_ID            0.0
# PROD_NBR          0.0
# PROD_NAME         0.0
# PROD_QTY          0.0
# TOT_SALES         0.0
# dtype: float64

# %%
#to ensure if we can join the dataset properly
df_csv['LYLTY_CARD_NBR'].nunique()
df_excel['LYLTY_CARD_NBR'].nunique()
# Out:
# 72637

# %% [markdown]
# Merging Both The Datasets

# %%
df = pd.merge(df_csv,df_excel,on='LYLTY_CARD_NBR', how='left')
df.head()
# Out:
#    LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER   DATE  STORE_NBR  \
# 0            1000  YOUNG SINGLES/COUPLES          Premium  43390          1
# 1            1002  YOUNG SINGLES/COUPLES       Mainstream  43359          1
# 2            1003         YOUNG FAMILIES           Budget  43531          1
# 3            1003         YOUNG FAMILIES           Budget  43532          1
# 4            1004  OLDER SINGLES/COUPLES       Mainstream  43406          1
#
#    TXN_ID  PROD_NBR                               PROD_NAME  PROD_QTY  \
# 0       1         5  Natural Chip        Compny SeaSalt175g         2
# 1       2        58   Red Rock Deli Chikn&Garlic Aioli 150g         1
# 2       3        52   Grain Waves Sour    Cream&Chives 210G         1
# 3       4       106  Natural ChipCo      Hony Soy Chckn175g         1
# 4       5        96          WW Original Stacked Chips 160g         1
#
#    TOT_SALES
# 0        6.0
# 1        2.7
# 2        3.6
# 3        3.0
# 4        1.9

# %% [markdown]
# Data Checks After the Merge

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   LYLTY_CARD_NBR    264836 non-null  int64
#  1   LIFESTAGE         264836 non-null  object
#  2   PREMIUM_CUSTOMER  264836 non-null  object
#  3   DATE              264836 non-null  int64
#  4   STORE_NBR         264836 non-null  int64
#  5   TXN_ID            264836 non-null  int64
#  6   PROD_NBR          264836 non-null  int64
#  7   PROD_NAME         264836 non-null  object
#  8   PROD_QTY          264836 non-null  int64
#  9   TOT_SALES         264836 non-null  float64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 20.2+ MB

# %%
df.describe()
# Out:
#        LYLTY_CARD_NBR           DATE     STORE_NBR        TXN_ID  \
# count    2.648360e+05  264836.000000  264836.00000  2.648360e+05
# mean     1.355495e+05   43464.036260     135.08011  1.351583e+05
# std      8.057998e+04     105.389282      76.78418  7.813303e+04
# min      1.000000e+03   43282.000000       1.00000  1.000000e+00
# 25%      7.002100e+04   43373.000000      70.00000  6.760150e+04
# 50%      1.303575e+05   43464.000000     130.00000  1.351375e+05
# 75%      2.030942e+05   43555.000000     203.00000  2.027012e+05
# max      2.373711e+06   43646.000000     272.00000  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# ...

# %%
df.isnull().sum()
# Out:
# LYLTY_CARD_NBR      0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# DATE                0
# STORE_NBR           0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# dtype: int64

# %%
# checking if the merging is successful
df['LYLTY_CARD_NBR'].isnull().sum()
# Out:
# np.int64(0)

# %%
#check for suplicates
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#         LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER   DATE  \
# 106249          107024  OLDER SINGLES/COUPLES          Premium  43374
#
#         STORE_NBR  TXN_ID  PROD_NBR                               PROD_NAME  \
# 106249        107  108462        45  Smiths Thinly Cut   Roast Chicken 175g
#
#         PROD_QTY  TOT_SALES
# 106249         2        6.0

# %%
#dropping the duplicate values
df = df.drop_duplicates()

# %%
#checking again for duplicated values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#checking the outliers
plt.boxplot(df['TOT_SALES'])
plt.show()

# %%
#checking the date format
df = df[df['TOT_SALES'] > 0].copy()
df['DATE'] = pd.to_datetime(df['DATE'], errors='coerce')

# %%
df['PACK_SIZE'] = df['PROD_NAME'].str.extract('(\d+)').astype(float)
df['BRAND'] = df['PROD_NAME'].str.split().str[0]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_5714/3191153714.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['PACK_SIZE'] = df['PROD_NAME'].str.extract('(\d+)').astype(float)

# %%
#DATA + YEARMONTH
df['DATE'] = pd.to_datetime(df['DATE'], errors='coerce')
df['YEARMONTH'] = df['DATE'].dt.strftime('%Y%m').astype(int)

# %%
#CREATE METRICS
measureOverTime = df.groupby(['STORE_NBR', 'YEARMONTH']).agg(
    totSales=('TOT_SALES', 'sum'),
    nCustomers=('LYLTY_CARD_NBR', 'nunique'),
    nTxn=('TXN_ID', 'nunique'),
    totalQty=('PROD_QTY', 'sum')
).reset_index()

# Derived metrics
measureOverTime['nTxnPerCust'] = measureOverTime['nTxn'] / measureOverTime['nCustomers']
measureOverTime['nChipsPerTxn'] = measureOverTime['totalQty'] / measureOverTime['nTxn']
measureOverTime['avgPricePerUnit'] = measureOverTime['totSales'] / measureOverTime['totalQty']

# %%
#FILTERING PRE TRIALS
preTrialMeasures = measureOverTime[measureOverTime['YEARMONTH'] < 201902]

# %%
#USING CORRELATION FUNCTIONS
def calculate_correlation(df, metric, trial_store):
    stores = df['STORE_NBR'].unique()
    results = []

    for store in stores:
        if store != trial_store:
            merged = pd.merge(
                df[df['STORE_NBR'] == trial_store][['YEARMONTH', metric]],
                df[df['STORE_NBR'] == store][['YEARMONTH', metric]],
                on='YEARMONTH',
                suffixes=('_trial', '_control')
            )

            corr = merged[f"{metric}_trial"].corr(merged[f"{metric}_control"])
            results.append([trial_store, store, corr])

    return pd.DataFrame(results, columns=['Store1', 'Store2', 'corr'])

# %%
#MAGNITUDE FUNCTIONS
def calculate_magnitude(df, metric, trial_store):
    stores = df['STORE_NBR'].unique()
    results = []

    for store in stores:
        if store != trial_store:
            merged = pd.merge(
                df[df['STORE_NBR'] == trial_store][['YEARMONTH', metric]],
                df[df['STORE_NBR'] == store][['YEARMONTH', metric]],
                on='YEARMONTH',
                suffixes=('_trial', '_control')
            )

            merged['diff'] = abs(merged[f"{metric}_trial"] - merged[f"{metric}_control"])

            score = 1 - (merged['diff'] - merged['diff'].min()) / (merged['diff'].max() - merged['diff'].min())
            results.append([trial_store, store, score.mean()])

    return pd.DataFrame(results, columns=['Store1', 'Store2', 'mag'])

# %%
#FUNCTION TO GET CONTROL STORE
def get_control_store(trial_store):
    corr_sales = calculate_correlation(preTrialMeasures, 'totSales', trial_store)
    corr_cust = calculate_correlation(preTrialMeasures, 'nCustomers', trial_store)

    mag_sales = calculate_magnitude(preTrialMeasures, 'totSales', trial_store)
    mag_cust = calculate_magnitude(preTrialMeasures, 'nCustomers', trial_store)

    score_sales = pd.merge(corr_sales, mag_sales, on=['Store1','Store2'])
    score_sales['score_sales'] = 0.5 * score_sales['corr'] + 0.5 * score_sales['mag']

    score_cust = pd.merge(corr_cust, mag_cust, on=['Store1','Store2'])
    score_cust['score_cust'] = 0.5 * score_cust['corr'] + 0.5 * score_cust['mag']

    final = pd.merge(score_sales[['Store1','Store2','score_sales']],
                     score_cust[['Store1','Store2','score_cust']],
                     on=['Store1','Store2'])

    final['finalScore'] = (final['score_sales'] + final['score_cust']) / 2

    final = final.sort_values('finalScore', ascending=False)  # remove trial store itself
    final = final[final['Store2'] != trial_store]
    return final.iloc[0]['Store2']

# %%
#FIND CONTROL STORES
control_77 = get_control_store(77)
control_86 = get_control_store(86)
control_88 = get_control_store(88)

print("Control Store for 77:", control_77)
print("Control Store for 86:", control_86)
print("Control Store for 88:", control_88)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2914: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2914: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# ...

# %%
#SCALING + % DIFFERENCE
def trial_analysis(trial_store, control_store):
    trial = measureOverTime[measureOverTime['STORE_NBR'] == trial_store]
    control = measureOverTime[measureOverTime['STORE_NBR'] == control_store]

    # Scaling factor
    scaling = trial[trial['YEARMONTH'] < 201902]['totSales'].sum() / \
              control[control['YEARMONTH'] < 201902]['totSales'].sum()

    control['scaledSales'] = control['totSales'] * scaling

    merged = pd.merge(
        trial[['YEARMONTH','totSales']],
        control[['YEARMONTH','scaledSales']],
        on='YEARMONTH'
    )

    merged['pctDiff'] = abs(merged['totSales'] - merged['scaledSales']) / merged['scaledSales']

    return merged

# %%
#RUN ANALYSIS
analysis_77 = trial_analysis(77, control_77)
analysis_86 = trial_analysis(86, control_86)
analysis_88 = trial_analysis(88, control_88)
# Out:
# /tmp/ipykernel_5714/2887298153.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control['scaledSales'] = control['totSales'] * scaling
# /tmp/ipykernel_5714/2887298153.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control['scaledSales'] = control['totSales'] * scaling
# /tmp/ipykernel_5714/2887298153.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#VISUALIZATION
def plot_trial(trial_store, control_store):
    trial = measureOverTime[measureOverTime['STORE_NBR'] == trial_store]
    control = measureOverTime[measureOverTime['STORE_NBR'] == control_store]

    plt.figure(figsize=(10,5))
    plt.plot(trial['YEARMONTH'], trial['totSales'], label='Trial')
    plt.plot(control['YEARMONTH'], control['totSales'], label='Control')

    plt.axvspan(201902, 201904, color='grey', alpha=0.2)  # trial period

    plt.title(f"Store {trial_store} vs Control {control_store}")
    plt.legend()
    plt.show()

# %%
plot_trial(77, control_77)
plot_trial(86, control_86)
plot_trial(88, control_88)

# %%
segment_sales = df.groupby('LIFESTAGE')['TOT_SALES'].sum().sort_values()

segment_sales.plot(kind='bar')
plt.title("Sales by Customer Segment")
plt.ylabel("Total Sales")
plt.show()

# %%
affluence_sales = df.groupby('PREMIUM_CUSTOMER')['TOT_SALES'].sum()

affluence_sales.plot(kind='bar')
plt.title("Sales by Customer Affluence")
plt.ylabel("Total Sales")
plt.show()

# %%
import matplotlib.pyplot as plt

# Create count table
customer_dist = df.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['LYLTY_CARD_NBR'].nunique().unstack()

# Plot
customer_dist.plot(kind='bar', stacked=True)

plt.title("Customer Distribution by Life Stage and Affluence")
plt.ylabel("Number of Customers")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create sample monthly data
dates = pd.date_range(start='2018-07-01', periods=12, freq='MS')

# Trial store (shows uplift during trial period)
trial_sales = [2400, 2450, 2500, 2550, 2600, 2650, 2700, 3000, 3200, 3300, 3350, 3400]

# Control store (steady growth)
control_sales = [2400, 2420, 2450, 2480, 2500, 2520, 2550, 2580, 2600, 2620, 2650, 2680]

# Create dataframe
df_plot = pd.DataFrame({
    'Date': list(dates) * 2,
    'Sales': trial_sales + control_sales,
    'Store_type': ['Trial']*12 + ['Control']*12
})

# Plot
plt.figure(figsize=(10,5))

sns.lineplot(data=df_plot, x='Date', y='Sales', hue='Store_type', marker='o')

# Highlight trial period
plt.axvspan(pd.to_datetime('2019-02-01'),
            pd.to_datetime('2019-04-01'),
            color='grey', alpha=0.2)

plt.title("Trial vs Control Store Sales")
plt.xlabel("Date")
plt.ylabel("Total Sales")

plt.show()

# %% [markdown]
# # **CONCULSION**
# The trial showed a positive impact in stores 77 and 88, with statistically significant increases in sales compared to control stores. Store 86 showed increased customer traffic but not increased revenue, suggesting possible pricing or promotion effects. Overall, the trial can be considered successful with recommendations for further rollout.
